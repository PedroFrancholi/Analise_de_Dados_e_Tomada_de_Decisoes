# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroFrancholi/Analise_de_Dados_e_Tomada_de_Decisoes/blob/main/TDE_2505.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('natacao.csv')

# %%
df
# Out:
#            Sede   Ano Distancia  Estilo  Revesamento?     Genero Equipe  \
# 0         Tokyo  2020      100m  Costas             0  Masculino    ROC
# 1         Tokyo  2020      100m  Costas             0  Masculino    ROC
# 2         Tokyo  2020      100m  Costas             0  Masculino    USA
# 3         Tokyo  2020      100m  Costas             0  Masculino    ITA
# 4         Tokyo  2020      100m  Costas             0  Masculino    CHN
# ...         ...   ...       ...     ...           ...        ...    ...
# 4354  Stockholm  1912     4x100   Livre             1   Feminino    SWE
# 4355  Stockholm  1912     4x200   Livre             1  Masculino    AUS
# 4356  Stockholm  1912     4x200   Livre             1  Masculino    USA
# 4357  Stockholm  1912     4x200   Livre             1  Masculino    GBR
# 4358  Stockholm  1912     4x200   Livre             1  Masculino    GER
#
#                                                  Atleta            Tempo  \
# ...

# %% [markdown]
# 1)
# Sede..............Qualitativa Nominal /
# Ano...............Quantitativa Discreta /
# Distancia.........Quantitativa Discreta /
# Estilo............Qualitativa Nominal /
# Revesamento.......Quantitativa Discreta /
# Genero............Qualitativa Nominal /
# Equipe............Qualitativa Nominal /
# Atleta............Qualitativa Nominal /
# Tempo.............Quantitativa Continua /
# Posição...........Quantitativa Discreta

# %% [markdown]
# 2) Ano - Medida de Variabilidade ->  Porque a quantidade de anos é possivel realizar a mediana / Distância - Medida de Variabilidade ->  Porque a quantidade de anos é possivel realizar a mediana / Tempo - Medida de variabilidade -> É algo que pode variar, não tendo média exata / Posição - Medida de Posiçaõ -> Somente indica uma posição em espeficico

# %% [markdown]
# 3)

# %%
genero = df.loc[df['Genero']=='Masculino']
genero.describe()
# Out:
#                Ano  Revesamento?      Posicao
# count  2291.000000   2291.000000  2291.000000
# mean   1981.143605      0.173287     3.139241
# std      28.310164      0.378578     1.220026
# min    1912.000000      0.000000     0.000000
# 25%    1964.000000      0.000000     2.000000
# 50%    1984.000000      0.000000     4.000000
# 75%    2004.000000      0.000000     4.000000
# max    2020.000000      1.000000     5.000000

# %% [markdown]
# 4)

# %%
genero = df.loc[df['Genero']=='Feminino']
genero.describe()
# Out:
#                Ano  Revesamento?      Posicao
# count  2068.000000   2068.000000  2068.000000
# mean   1984.922631      0.165861     3.193424
# std      25.167687      0.372046     1.154833
# min    1912.000000      0.000000     0.000000
# 25%    1968.000000      0.000000     2.000000
# 50%    1988.000000      0.000000     4.000000
# 75%    2004.000000      0.000000     4.000000
# max    2020.000000      1.000000     5.000000

# %% [markdown]
# 6)

# %%
df['Distancia'].replace('100m',100).replace('4x100',400).replace('4x200',800).replace('1500m',1500)
# Out:
# 0       100
# 1       100
# 2       100
# 3       100
# 4       100
#        ...
# 4354    400
# 4355    800
# 4356    800
# 4357    800
# 4358    800
# Name: Distancia, Length: 4359, dtype: object

# %% [markdown]
# 8) Os tempos após os anos 2000, começaram a ficar estáveis, pois o gráfico começou a ficar com uma linha reta.
# A porcentagem da diferença entre o tempo masculino e feminino aparentemente permaneceram constantes após 1970
